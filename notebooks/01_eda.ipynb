# %% [markdown]
# # 🛰️ Clouden Project – EDA Notebook
# This notebook explores CloudSEN12+ Sentinel-2 imagery and cloud masks.

# %%
import matplotlib.pyplot as plt
import rasterio
from scripts.data_loader import load_tiff

# Example paths (update with your real ones)
img = load_tiff('data/sample_tile.tif')
mask = load_tiff('data/sample_tile_mask.tif')[..., 0]

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(img[..., :3]/10000); plt.title('RGB Tile')
plt.subplot(1,2,2); plt.imshow(mask, cmap='gray'); plt.title('Cloud Mask')
plt.show()
